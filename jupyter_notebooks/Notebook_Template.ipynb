# %% [markdown]
# # **(ADD THE NOTEBOOK NAME HERE)**

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here. ---- needed to install Jupyter dependencies, as kernel kept dying, python kernel started, then the necessary packages were downloaded
# we dropped several; columns as a aim was to focus on partiuclar parameters (make these clear and why - psycholigcal factors and current daya to day matter sthat might cause issue) nd to afford a more simplistic, less technical, viewer friendly application
# we also extracted a fractioned/ sampled state due to this
# the notenook also acts similar to a pre-analysis point
# add in readme not to rule out outside factors like head injury, or other comordid disease such as diabetes, or family history (also included in orginal dataset)

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\F_bee\\Documents\\vs-code\\vs-code-projects\\healthcare-and-public-health\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chdir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\F_bee\\Documents\\vs-code\\vs-code-projects\\healthcare-and-public-health'

# %% [markdown]
# # Section 1

# %% [markdown]
# ## Package Installation Instructions
#
# **⚠️ IMPORTANT: Before running the cells below, you MUST restart the kernel!**
#
# **How to restart the kernel:**
# 1. Click on the **"Kernel"** menu at the top
# 2. Select **"Restart Kernel"**
# 3. Confirm the restart
# 4. **Then** run the 3 STEP cells below in order
#
# **Why restart is required:**
# - Windows locks files that are currently in use
# - NumPy is loaded in the current kernel session
# - Restarting clears memory and releases file locks

# %%
# STEP 1: Upgrade numpy first (run after kernel restart)
# %pip install --upgrade numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.3.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.3.2-cp312-cp312-win_amd64.whl (12.8 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.3.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# feature-engine 1.8.3 requires scipy>=1.4.1, which is not installed.
# feature-engine 1.8.3 requires statsmodels>=0.11.1, which is not installed.
# scikit-learn 1.7.1 requires joblib>=1.2.0, which is not installed.
# scikit-learn 1.7.1 requires scipy>=1.8.0, which is not installed.
# seaborn 0.13.2 requires matplotlib!=3.6.1,>=3.4, which is not installed.

# %%
# STEP 2: Install other packages (run after numpy upgrade completes)
# %pip install pandas matplotlib seaborn scikit-learn plotly feature-engine
# Out:
# Requirement already satisfied: pandas in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (2.2.2)
# Collecting matplotlib
#   Using cached matplotlib-3.10.5-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: seaborn in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (1.7.1)
# Requirement already satisfied: plotly in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (6.2.0)
# Requirement already satisfied: feature-engine in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (1.8.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from pandas) (2025.2)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.59.0-cp312-cp312-win_amd64.whl.metadata (110 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from plotly) (2.0.1)
# Collecting statsmodels>=0.11.1 (from feature-engine)
#   Using cached statsmodels-0.14.5-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting patsy>=0.5.6 (from statsmodels>=0.11.1->feature-engine)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Using cached matplotlib-3.10.5-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.59.0-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl (38.5 MB)
# Using cached statsmodels-0.14.5-cp312-cp312-win_amd64.whl (9.6 MB)
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: scipy, patsy, kiwisolver, joblib, fonttools, cycler, contourpy, matplotlib, statsmodels
#
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    -------- ------------------------------- 2/9 [kiwisolver]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ---------------------- ----------------- 5/9 [cycler]
#    -------------------------- ------------- 6/9 [contourpy]
#    -------------------------- ------------- 6/9 [contourpy]
#    -------------------------- ------------- 6/9 [contourpy]
#    -------------------------- ------------- 6/9 [contourpy]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ---------------------------------------- 9/9 [statsmodels]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.0 joblib-1.5.1 kiwisolver-1.4.8 matplotlib-3.10.5 patsy-1.0.1 scipy-1.16.1 statsmodels-0.14.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# STEP 3: Test all imports (run after all packages are installed)
import numpy as np
import pandas as pd
import matplotlib as mb
import matplotlib.pyplot as plt
import plotly as pl
import seaborn as sns
import sklearn as sk
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import feature_engine as fe
import sys
sys.path.append('../')

print("All packages imported successfully!")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"Matplotlib version: {mb.__version__}")
print(f"Seaborn version: {sns.__version__}")
print(f"Scikit-learn version: {sk.__version__}")
print(f"Plotly version: {pl.__version__}")
print(f"Feature-engine version: {fe.__version__}")
# Out:
# All packages imported successfully!
# NumPy version: 1.26.4
# Pandas version: 2.1.4
# Matplotlib version: 3.10.5
# Seaborn version: 0.13.2
# Scikit-learn version: 1.7.1
# Plotly version: 6.2.0
# Feature-engine version: 1.8.3

# %%
df = pd.read_csv("../inputs/alzheimers_disease_data.csv")
df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  ...  \
# 0              13.297218          6.327112     1.347214  ...
# 1               4.542524          7.619885     0.518767  ...
# 2              19.555085          7.844988     1.826335  ...
# 3              12.209266          8.428001     7.435604  ...
# 4              18.454356          6.310461     0.795498  ...
# ...                  ...               ...          ...  ...
# 2144            1.561126          4.049964     6.555306  ...
# 2145           18.767261          1.360667     2.904662  ...
# 2146            4.594670          9.886002     8.120025  ...
# 2147            8.674505          6.354282     1.263427  ...
# 2148            7.890703          6.570993     7.941404  ...
#
#       MemoryComplaints  BehavioralProblems       ADL  Confusion  \
# 0                    0                   0  1.725883          0
# 1                    0                   0  2.592424          0
# 2                    0                   0  7.119548          0
# 3                    0                   1  6.481226          0
# 4                    0                   0  0.014691          0
# ...                ...                 ...       ...        ...
# 2144                 0                   0  4.492838          1
# 2145                 0                   1  9.204952          0
# 2146                 0                   0  5.036334          0
# 2147                 0                   0  3.785399          0
# 2148                 0                   1  8.327563          0
#
#       Disorientation  PersonalityChanges  DifficultyCompletingTasks  \
# 0                  0                   0                          1
# 1                  0                   0                          0
# 2                  1                   0                          1
# 3                  0                   0                          0
# 4                  0                   1                          1
# ...              ...                 ...                        ...
# 2144               0                   0                          0
# 2145               0                   0                          0
# 2146               0                   0                          0
# 2147               0                   0                          0
# 2148               1                   0                          0
#
#       Forgetfulness  Diagnosis  DoctorInCharge
# 0                 0          0       XXXConfid
# 1                 1          0       XXXConfid
# 2                 0          0       XXXConfid
# 3                 0          0       XXXConfid
# 4                 0          0       XXXConfid
# ...             ...        ...             ...
# 2144              0          1       XXXConfid
# 2145              0          1       XXXConfid
# 2146              0          1       XXXConfid
# 2147              1          1       XXXConfid
# 2148              1          0       XXXConfid
#
# [2149 rows x 35 columns]

# %%
df = df.sample(frac=0.25, random_state=10)
df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 613        5364   61       1          1               0  29.270540        0
# 1018       5769   81       1          0               0  34.641073        0
# 264        5015   81       0          1               0  22.923111        0
# 1758       6509   62       0          0               2  23.587924        0
# 1441       6192   80       1          3               2  23.715891        1
# ...         ...  ...     ...        ...             ...        ...      ...
# 205        4956   83       1          0               2  26.662335        1
# 1307       6058   83       0          0               1  37.493343        0
# 244        4995   90       0          0               0  31.024315        0
# 1450       6201   70       0          3               0  31.001219        0
# 1392       6143   65       1          3               1  23.974278        1
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  ...  \
# 613            14.782028          7.315484     2.976619  ...
# 1018            7.383103          2.473479     5.280584  ...
# 264             9.314832          8.917378     3.807813  ...
# 1758            1.236318          0.666426     3.360432  ...
# 1441           12.339372          5.970801     1.625098  ...
# ...                  ...               ...          ...  ...
# 205             5.934112          3.410777     8.772173  ...
# 1307            0.748050          8.592732     0.896680  ...
# 244             8.861309          9.552672     2.596869  ...
# 1450            1.238807          8.572866     3.162399  ...
# 1392           17.277586          2.334897     8.221101  ...
#
#       MemoryComplaints  BehavioralProblems       ADL  Confusion  \
# 613                  1                   0  0.775005          0
# 1018                 0                   0  3.389056          0
# 264                  0                   1  8.681801          0
# 1758                 0                   0  3.983733          1
# 1441                 0                   0  2.744058          0
# ...                ...                 ...       ...        ...
# 205                  0                   0  5.237469          0
# 1307                 0                   0  7.295883          0
# 244                  1                   0  1.284572          0
# 1450                 0                   0  2.310358          1
# 1392                 0                   0  6.763787          0
#
#       Disorientation  PersonalityChanges  DifficultyCompletingTasks  \
# 613                1                   0                          0
# 1018               0                   0                          0
# 264                0                   0                          0
# 1758               0                   0                          0
# 1441               0                   0                          0
# ...              ...                 ...                        ...
# 205                0                   1                          0
# 1307               0                   0                          0
# 244                0                   1                          0
# 1450               0                   0                          0
# 1392               0                   0                          0
#
#       Forgetfulness  Diagnosis  DoctorInCharge
# 613               0          1       XXXConfid
# 1018              0          0       XXXConfid
# 264               0          1       XXXConfid
# 1758              0          0       XXXConfid
# 1441              1          0       XXXConfid
# ...             ...        ...             ...
# 205               0          0       XXXConfid
# 1307              0          0       XXXConfid
# 244               0          1       XXXConfid
# 1450              0          0       XXXConfid
# 1392              0          0       XXXConfid
#
# [537 rows x 35 columns]

# %%
df
print("Available columns:")
print(df.columns.tolist())
print(f"\nDataset shape: {df.shape}")
# Out:
# Available columns:
# ['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality', 'SleepQuality', 'FamilyHistoryAlzheimers', 'CardiovascularDisease', 'Diabetes', 'Depression', 'HeadInjury', 'Hypertension', 'SystolicBP', 'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment', 'MemoryComplaints', 'BehavioralProblems', 'ADL', 'Confusion', 'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks', 'Forgetfulness', 'Diagnosis', 'DoctorInCharge']
#
# Dataset shape: (2149, 35)

# %%
df = df.rename(columns={"ADL": "ActivitiesOfDailyLiving"}) # Make more descriptive
df
# Out:
#       PatientID  Age  Gender  Ethnicity        BMI  Smoking  \
# 0          4751   73       0          0  22.927749        0
# 1          4752   89       0          0  26.827681        0
# 2          4753   73       0          3  17.795882        0
# 3          4754   74       1          0  33.800817        1
# 4          4755   89       0          0  20.716974        0
# ...         ...  ...     ...        ...        ...      ...
# 2144       6895   61       0          0  39.121757        0
# 2145       6896   75       0          0  17.857903        0
# 2146       6897   77       0          0  15.476479        0
# 2147       6898   78       1          3  15.299911        0
# 2148       6899   72       0          0  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  \
# 0              13.297218          6.327112     1.347214
# 1               4.542524          7.619885     0.518767
# 2              19.555085          7.844988     1.826335
# 3              12.209266          8.428001     7.435604
# 4              18.454356          6.310461     0.795498
# ...                  ...               ...          ...
# 2144            1.561126          4.049964     6.555306
# 2145           18.767261          1.360667     2.904662
# 2146            4.594670          9.886002     8.120025
# 2147            8.674505          6.354282     1.263427
# 2148            7.890703          6.570993     7.941404
#
#       CardiovascularDisease  ...  CholesterolTotal       MMSE  \
# 0                         0  ...        242.366840  21.463532
# 1                         0  ...        231.162595  20.613267
# 2                         0  ...        284.181858   7.356249
# 3                         0  ...        159.582240  13.991127
# 4                         0  ...        237.602184  13.517609
# ...                     ...  ...               ...        ...
# 2144                      0  ...        280.476824   1.201190
# 2145                      0  ...        186.384436   6.458060
# 2146                      0  ...        237.024558  17.011003
# 2147                      1  ...        242.197192   4.030491
# 2148                      0  ...        283.396797  11.114777
#
#       FunctionalAssessment  MemoryComplaints  BehavioralProblems       ADL  \
# 0                 6.518877                 0                   0  1.725883
# 1                 7.118696                 0                   0  2.592424
# 2                 5.895077                 0                   0  7.119548
# 3                 8.965106                 0                   1  6.481226
# 4                 6.045039                 0                   0  0.014691
# ...                    ...               ...                 ...       ...
# 2144              0.238667                 0                   0  4.492838
# 2145              8.687480                 0                   1  9.204952
# 2146              1.972137                 0                   0  5.036334
# 2147              5.173891                 0                   0  3.785399
# 2148              6.307543                 0                   1  8.327563
#
#       PersonalityChanges  DifficultyCompletingTasks  Diagnosis  DoctorInCharge
# 0                      0                          1          0       XXXConfid
# 1                      0                          0          0       XXXConfid
# 2                      0                          1          0       XXXConfid
# 3                      0                          0          0       XXXConfid
# 4                      1                          1          0       XXXConfid
# ...                  ...                        ...        ...             ...
# 2144                   0                          0          1       XXXConfid
# 2145                   0                          0          1       XXXConfid
# 2146                   0                          0          1       XXXConfid
# 2147                   0                          0          1       XXXConfid
# 2148                   0                          0          0       XXXConfid
#
# [2149 rows x 21 columns]

# %% [markdown]
# Drop columns for a more greater focus on certain/particular areas, as well as a more streamlined observation and analysis

# %%
df.drop(columns=["EducationLevel", "SleepQuality", "FamilyHistoryAlzheimers", "Diabetes", "HeadInjury", "Hypertension", "SystolicBP", "DiastolicBP", "CholesterolLDL", "CholesterolHDL", "CholesterolTriglycerides", "Confusion", "Disorientation", "Forgetfulness"], inplace=True)
df
print("Available columns:")
print(df.columns.tolist())
print(f"\nDataset shape: {df.shape}")
# Out:
# Available columns:
# ['PatientID', 'Age', 'Gender', 'Ethnicity', 'BMI', 'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality', 'CardiovascularDisease', 'Depression', 'CholesterolTotal', 'MMSE', 'FunctionalAssessment', 'MemoryComplaints', 'BehavioralProblems', 'ADL', 'PersonalityChanges', 'DifficultyCompletingTasks', 'Diagnosis', 'DoctorInCharge']
#
# Dataset shape: (2149, 21)

# %%
df
# Out:
#       PatientID  Age  Gender  Ethnicity        BMI  Smoking  \
# 0          4751   73       0          0  22.927749        0
# 1          4752   89       0          0  26.827681        0
# 2          4753   73       0          3  17.795882        0
# 3          4754   74       1          0  33.800817        1
# 4          4755   89       0          0  20.716974        0
# ...         ...  ...     ...        ...        ...      ...
# 2144       6895   61       0          0  39.121757        0
# 2145       6896   75       0          0  17.857903        0
# 2146       6897   77       0          0  15.476479        0
# 2147       6898   78       1          3  15.299911        0
# 2148       6899   72       0          0  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  \
# 0              13.297218          6.327112     1.347214
# 1               4.542524          7.619885     0.518767
# 2              19.555085          7.844988     1.826335
# 3              12.209266          8.428001     7.435604
# 4              18.454356          6.310461     0.795498
# ...                  ...               ...          ...
# 2144            1.561126          4.049964     6.555306
# 2145           18.767261          1.360667     2.904662
# 2146            4.594670          9.886002     8.120025
# 2147            8.674505          6.354282     1.263427
# 2148            7.890703          6.570993     7.941404
#
#       CardiovascularDisease  ...  CholesterolTotal       MMSE  \
# 0                         0  ...        242.366840  21.463532
# 1                         0  ...        231.162595  20.613267
# 2                         0  ...        284.181858   7.356249
# 3                         0  ...        159.582240  13.991127
# 4                         0  ...        237.602184  13.517609
# ...                     ...  ...               ...        ...
# 2144                      0  ...        280.476824   1.201190
# 2145                      0  ...        186.384436   6.458060
# 2146                      0  ...        237.024558  17.011003
# 2147                      1  ...        242.197192   4.030491
# 2148                      0  ...        283.396797  11.114777
#
#       FunctionalAssessment  MemoryComplaints  BehavioralProblems       ADL  \
# 0                 6.518877                 0                   0  1.725883
# 1                 7.118696                 0                   0  2.592424
# 2                 5.895077                 0                   0  7.119548
# 3                 8.965106                 0                   1  6.481226
# 4                 6.045039                 0                   0  0.014691
# ...                    ...               ...                 ...       ...
# 2144              0.238667                 0                   0  4.492838
# 2145              8.687480                 0                   1  9.204952
# 2146              1.972137                 0                   0  5.036334
# 2147              5.173891                 0                   0  3.785399
# 2148              6.307543                 0                   1  8.327563
#
#       PersonalityChanges  DifficultyCompletingTasks  Diagnosis  DoctorInCharge
# 0                      0                          1          0       XXXConfid
# 1                      0                          0          0       XXXConfid
# 2                      0                          1          0       XXXConfid
# 3                      0                          0          0       XXXConfid
# 4                      1                          1          0       XXXConfid
# ...                  ...                        ...        ...             ...
# 2144                   0                          0          1       XXXConfid
# 2145                   0                          0          1       XXXConfid
# 2146                   0                          0          1       XXXConfid
# 2147                   0                          0          1       XXXConfid
# 2148                   0                          0          0       XXXConfid
#
# [2149 rows x 21 columns]

# %%
df.min()
df[["Age", "BMI"]].min() #edit
# Out:
# PatientID                          4751
# Age                                  60
# Gender                                0
# Ethnicity                             0
# EducationLevel                        0
# BMI                           15.008851
# Smoking                               0
# AlcoholConsumption             0.002003
# PhysicalActivity               0.003616
# DietQuality                    0.009385
# SleepQuality                   4.002629
# FamilyHistoryAlzheimers               0
# CardiovascularDisease                 0
# Diabetes                              0
# Depression                            0
# HeadInjury                            0
# Hypertension                          0
# SystolicBP                           90
# DiastolicBP                          60
# CholesterolTotal             150.093316
# CholesterolLDL                50.230707
# CholesterolHDL                20.003434
# CholesterolTriglycerides      50.407194
# MMSE                           0.005312
# FunctionalAssessment            0.00046
# MemoryComplaints                      0
# BehavioralProblems                    0
# ADL                            0.001288
# Confusion                             0
# Disorientation                        0
# PersonalityChanges                    0
# DifficultyCompletingTasks             0
# Forgetfulness                         0
# Diagnosis                             0
# DoctorInCharge                XXXConfid
# dtype: object

# %%
df.max()
# Out:
# PatientID                          6899
# Age                                  90
# Gender                                1
# Ethnicity                             3
# EducationLevel                        3
# BMI                           39.992767
# Smoking                               1
# AlcoholConsumption            19.989293
# PhysicalActivity               9.987429
# DietQuality                    9.998346
# SleepQuality                    9.99984
# FamilyHistoryAlzheimers               1
# CardiovascularDisease                 1
# Diabetes                              1
# Depression                            1
# HeadInjury                            1
# Hypertension                          1
# SystolicBP                          179
# DiastolicBP                         119
# CholesterolTotal             299.993352
# CholesterolLDL               199.965665
# CholesterolHDL                99.980324
# CholesterolTriglycerides     399.941862
# MMSE                          29.991381
# FunctionalAssessment           9.996467
# MemoryComplaints                      1
# BehavioralProblems                    1
# ADL                            9.999747
# Confusion                             1
# Disorientation                        1
# PersonalityChanges                    1
# DifficultyCompletingTasks             1
# Forgetfulness                         1
# Diagnosis                             1
# DoctorInCharge                XXXConfid
# dtype: object

# %% [markdown]
# Check for duplicated rows and return the number of them.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Check for missing cells in each column and return the number of them.

# %%
df.isnull().sum()
# Out:
# PatientID                    0
# Age                          0
# Gender                       0
# Ethnicity                    0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# CardiovascularDisease        0
# Depression                   0
# CholesterolTotal             0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# PersonalityChanges           0
# DifficultyCompletingTasks    0
# Diagnosis                    0
# DoctorInCharge               0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %%
df
# Out:
#       PatientID  Age  Gender  Ethnicity        BMI  Smoking  \
# 0          4751   73       0          0  22.927749        0
# 1          4752   89       0          0  26.827681        0
# 2          4753   73       0          3  17.795882        0
# 3          4754   74       1          0  33.800817        1
# 4          4755   89       0          0  20.716974        0
# ...         ...  ...     ...        ...        ...      ...
# 2144       6895   61       0          0  39.121757        0
# 2145       6896   75       0          0  17.857903        0
# 2146       6897   77       0          0  15.476479        0
# 2147       6898   78       1          3  15.299911        0
# 2148       6899   72       0          0  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  \
# 0              13.297218          6.327112     1.347214
# 1               4.542524          7.619885     0.518767
# 2              19.555085          7.844988     1.826335
# 3              12.209266          8.428001     7.435604
# 4              18.454356          6.310461     0.795498
# ...                  ...               ...          ...
# 2144            1.561126          4.049964     6.555306
# 2145           18.767261          1.360667     2.904662
# 2146            4.594670          9.886002     8.120025
# 2147            8.674505          6.354282     1.263427
# 2148            7.890703          6.570993     7.941404
#
#       CardiovascularDisease  ...  CholesterolTotal       MMSE  \
# 0                         0  ...        242.366840  21.463532
# 1                         0  ...        231.162595  20.613267
# 2                         0  ...        284.181858   7.356249
# 3                         0  ...        159.582240  13.991127
# 4                         0  ...        237.602184  13.517609
# ...                     ...  ...               ...        ...
# 2144                      0  ...        280.476824   1.201190
# 2145                      0  ...        186.384436   6.458060
# 2146                      0  ...        237.024558  17.011003
# 2147                      1  ...        242.197192   4.030491
# 2148                      0  ...        283.396797  11.114777
#
#       FunctionalAssessment  MemoryComplaints  BehavioralProblems       ADL  \
# 0                 6.518877                 0                   0  1.725883
# 1                 7.118696                 0                   0  2.592424
# 2                 5.895077                 0                   0  7.119548
# 3                 8.965106                 0                   1  6.481226
# 4                 6.045039                 0                   0  0.014691
# ...                    ...               ...                 ...       ...
# 2144              0.238667                 0                   0  4.492838
# 2145              8.687480                 0                   1  9.204952
# 2146              1.972137                 0                   0  5.036334
# 2147              5.173891                 0                   0  3.785399
# 2148              6.307543                 0                   1  8.327563
#
#       PersonalityChanges  DifficultyCompletingTasks  Diagnosis  DoctorInCharge
# 0                      0                          1          0       XXXConfid
# 1                      0                          0          0       XXXConfid
# 2                      0                          1          0       XXXConfid
# 3                      0                          0          0       XXXConfid
# 4                      1                          1          0       XXXConfid
# ...                  ...                        ...        ...             ...
# 2144                   0                          0          1       XXXConfid
# 2145                   0                          0          1       XXXConfid
# 2146                   0                          0          1       XXXConfid
# 2147                   0                          0          1       XXXConfid
# 2148                   0                          0          0       XXXConfid
#
# [2149 rows x 21 columns]

# %%
# Replace values in categorical columns for better readability
# Gender mapping
if 'Gender' in df.columns:
    df['Gender'] = df['Gender'].replace({0: 'Male', 1: 'Female'})

# Ethnicity mapping
if 'Ethnicity' in df.columns:
    df['Ethnicity'] = df['Ethnicity'].replace({
        0: 'Caucasian', 1: 'African American', 2: 'Asian', 3: 'Other'
    })

# Binary columns (0/1 to No/Yes)
binary_cols = ['Smoking', 'CardiovascularDisease', 'Depression', 
               'MemoryComplaints', 'BehavioralProblems', 'PersonalityChanges', 
               'DifficultyCompletingTasks']

for col in binary_cols:
    if col in df.columns:
        df[col] = df[col].replace({0: 'No', 1: 'Yes'})

# Diagnosis mapping
if 'Diagnosis' in df.columns:
    df['Diagnosis'] = df['Diagnosis'].replace({0: 'No Dementia', 1: 'Dementia'})

df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity        BMI Smoking  AlcoholConsumption  \
# 0       4751   73    Male  Caucasian  22.927749      No           13.297218
# 1       4752   89    Male  Caucasian  26.827681      No            4.542524
# 2       4753   73    Male      Other  17.795882      No           19.555085
# 3       4754   74  Female  Caucasian  33.800817     Yes           12.209266
# 4       4755   89    Male  Caucasian  20.716974      No           18.454356
#
#    PhysicalActivity  DietQuality CardiovascularDisease  ... CholesterolTotal  \
# 0          6.327112     1.347214                    No  ...       242.366840
# 1          7.619885     0.518767                    No  ...       231.162595
# 2          7.844988     1.826335                    No  ...       284.181858
# 3          8.428001     7.435604                    No  ...       159.582240
# 4          6.310461     0.795498                    No  ...       237.602184
#
#         MMSE  FunctionalAssessment  MemoryComplaints BehavioralProblems  \
# 0  21.463532              6.518877                No                 No
# 1  20.613267              7.118696                No                 No
# 2   7.356249              5.895077                No                 No
# 3  13.991127              8.965106                No                Yes
# 4  13.517609              6.045039                No                 No
#
#         ADL  PersonalityChanges DifficultyCompletingTasks    Diagnosis  \
# 0  1.725883                  No                       Yes  No Dementia
# 1  2.592424                  No                        No  No Dementia
# 2  7.119548                  No                       Yes  No Dementia
# 3  6.481226                  No                        No  No Dementia
# 4  0.014691                 Yes                       Yes  No Dementia
#
#   DoctorInCharge
# 0      XXXConfid
# 1      XXXConfid
# 2      XXXConfid
# 3      XXXConfid
# 4      XXXConfid
#
# [5 rows x 21 columns]

# %%
# drop specific columns
def drop_columns(df):
    return df.drop(columns=["EducationLevel", "SleepQuality", "FamilyHistoryAlzheimers", "Diabetes", "HeadInjury", "Hypertension", "SystolicBP", "DiastolicBP", "CholesterolLDL", "CholesterolHDL", "CholesterolTriglycerides", "Confusion", "Disorientation", "Forgetfulness"], inplace=True, errors="ignore")

# convert data types
def convert_data_types(df):
	    if "PatientID" in df.columns:
        	df["PatientID"] = df["PatientID"].astype(str)
	    if "Age" in df.columns:
        	df["Age"] = df["Age"].astype(int)
	    if "Gender" in df.columns:
        	df["Gender"] = df["Gender"].astype(str)
	    if "Ethnicity" in df.columns:
        	df["Ethnicity"] = df["Ethnicity"].astype(str)
	    if "BMI" in df.columns:
        	df["BMI"] = df["BMI"].astype(float)
	    if "Smoking" in df.columns:
        	df["Smoking"] = df["Smoking"].astype(str)
	    if "AlcoholConsumption" in df.columns:
        	df["AlcoholConsumption"] = df["AlcoholConsumption"].astype(float)
	    if "PhysicalActivity" in df.columns:
        	df["PhysicalActivity"] = df["PhysicalActivity"].astype(int)
	    if "DietQuality" in df.columns:
        	df["DietQuality"] = df["DietQuality"].astype(str)
	    if "CardiovascularDisease" in df.columns:
        	df["CardiovascularDisease"] = df["CardiovascularDisease"].astype(str)
	if "Depression" in df.columns:
        	df["Depression"] = df["Depression"].astype(str)
	if "Cholesteroltotal" in df.columns:
        	df["Cholesteroltotal"] = df["Cholesteroltotal"].astype(float)
	if "MMSE" in df.columns:
        	df["MMSE"] = df["MMSE"].astype(int)
	if "FunctionalAssessment" in df.columns:
        	df["FunctionalAssessment"] = df["FunctionalAssessment"].astype(int)
	if "MemoryComplaints" in df.columns:
        	df["MemoryComplaints"] = df["MemoryComplaints"].astype(str)
	if "BehavioralProblems" in df.columns:
        	df["BehavioralProblems"] = df["BehavioralProblems"].astype(str)
	if "ADL" in df.columns:
        	df["ADL"] = df["ADL"].astype(int)
	if "PersonalityChanges" in df.columns:
        	df["PersonalityChanges"] = df["PersonalityChanges"].astype(int)
	if "DifficultyCompletingTasks" in df.columns:
        	df["DifficultyCompletingTasks"] = df["DifficultyCompletingTasks"].astype(int)
	if "Diagnosis" in df.columns:
        	df["Diagnosis"] = df["Diagnosis"].astype(str)
	if "DoctorInCharge" in df.columns:
        	df["DoctorInCharge"] = df["DoctorInCharge"].astype(str)
    return df

# remove outliers using IQR method
def remove_outliers(df):
    columns = ["BMI", "CholesterolTotal"]
    df_one = df.copy()
    for col in columns:
        if col in df_one.columns: 
            Q1 = df_one[col].quantile(0.25)
            Q3 = df_one[col].quantile(0.75)
            IQR = Q3 - Q1
            df_two = (df_one[col] >= Q1 - 1.5 * IQR) & (df_one[col] <= Q3 + 1.5 * IQR)
            df_one = df_one[df_two]  
    return df_one

# rename columns
def rename_columns(df):
    return df.rename(columns={
	"PatientID": "Patient_ID",
        "Age": "Patient_Age",
	"AlcoholConsumption": "Alcohol_Consumption",
	"PhysicalActivity": "Physical_Activity",
	"DietQuality": "Diet_Quality",
	"CardiovascularDisease": "Cardiovascular_Disease",
	"CholesterolTotal": "Cholesterol_Total",
	"FunctionalAssessment": "Functional_Assessment",
	"MemoryComplaints": "Memory_Complaints",
	"BehavioralProblems": "Behavioral_Problems",
	"ADL":  "Activities_Of_Daily_Living",
	"PersonalityChanges": "Personality_Changes",
	"DifficultyCompletingTasks": "Difficulty_Completing_Tasks",
	"DoctorInCharge": "Doctor_In_Charge"   
    })

# drop missing values
def drop_missing_values(df):
    return df.dropna()

# remove duplicates
def remove_duplicates(df):
    return df.drop_duplicates()

# round numerical values
def round_values(df):
    return df.round(2)
# Out:
#   File <string>:49
#     return df
#              ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)
#
# the data within the table had already been scaled and encoded but for demonstrative purposes as well as to satisfy its use, we've added this transformer to the pipeline - say what it does
#
# # capitalize column names
# def capitalize_columns(df):
#     df.columns = [col.title() for col in df.columns]
#     return df
#
# # drop missing values
# def drop_missing_values(df):
#     return df.dropna()g
#
# # remove duplicates
# def remove_duplicates(df):
#     return df.drop_duplicates() ------------ included these as quality assurance measures

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
