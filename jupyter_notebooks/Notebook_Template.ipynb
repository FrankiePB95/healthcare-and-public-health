# %% [markdown]
# # **(ADD THE NOTEBOOK NAME HERE)**

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here. ---- needed to install Jupyter dependencies, as kernel kept dying, python kernel started, then the necessary packages were downloaded

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\F_bee\\Documents\\vs-code\\vs-code-projects\\healthcare-and-public-health\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chdir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\F_bee\\Documents\\vs-code\\vs-code-projects\\healthcare-and-public-health'

# %% [markdown]
# # Section 1

# %% [markdown]
# ## Package Installation Instructions
#
# **⚠️ IMPORTANT: Before running the cells below, you MUST restart the kernel!**
#
# **How to restart the kernel:**
# 1. Click on the **"Kernel"** menu at the top
# 2. Select **"Restart Kernel"**
# 3. Confirm the restart
# 4. **Then** run the 3 STEP cells below in order
#
# **Why restart is required:**
# - Windows locks files that are currently in use
# - NumPy is loaded in the current kernel session
# - Restarting clears memory and releases file locks

# %%
# STEP 1: Upgrade numpy first (run after kernel restart)
# %pip install --upgrade numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.3.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.3.2-cp312-cp312-win_amd64.whl (12.8 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.3.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# feature-engine 1.8.3 requires scipy>=1.4.1, which is not installed.
# feature-engine 1.8.3 requires statsmodels>=0.11.1, which is not installed.
# scikit-learn 1.7.1 requires joblib>=1.2.0, which is not installed.
# scikit-learn 1.7.1 requires scipy>=1.8.0, which is not installed.
# seaborn 0.13.2 requires matplotlib!=3.6.1,>=3.4, which is not installed.

# %%
# STEP 2: Install other packages (run after numpy upgrade completes)
# %pip install pandas matplotlib seaborn scikit-learn plotly feature-engine
# Out:
# Requirement already satisfied: pandas in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (2.2.2)
# Collecting matplotlib
#   Using cached matplotlib-3.10.5-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: seaborn in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (1.7.1)
# Requirement already satisfied: plotly in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (6.2.0)
# Requirement already satisfied: feature-engine in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (1.8.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from pandas) (2025.2)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.59.0-cp312-cp312-win_amd64.whl.metadata (110 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from plotly) (2.0.1)
# Collecting statsmodels>=0.11.1 (from feature-engine)
#   Using cached statsmodels-0.14.5-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\f_bee\documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting patsy>=0.5.6 (from statsmodels>=0.11.1->feature-engine)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Using cached matplotlib-3.10.5-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.59.0-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl (38.5 MB)
# Using cached statsmodels-0.14.5-cp312-cp312-win_amd64.whl (9.6 MB)
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: scipy, patsy, kiwisolver, joblib, fonttools, cycler, contourpy, matplotlib, statsmodels
#
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---------------------------------------- 0/9 [scipy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    ---- ----------------------------------- 1/9 [patsy]
#    -------- ------------------------------- 2/9 [kiwisolver]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ------------- -------------------------- 3/9 [joblib]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ----------------- ---------------------- 4/9 [fonttools]
#    ---------------------- ----------------- 5/9 [cycler]
#    -------------------------- ------------- 6/9 [contourpy]
#    -------------------------- ------------- 6/9 [contourpy]
#    -------------------------- ------------- 6/9 [contourpy]
#    -------------------------- ------------- 6/9 [contourpy]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ------------------------------- -------- 7/9 [matplotlib]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ----------------------------------- ---- 8/9 [statsmodels]
#    ---------------------------------------- 9/9 [statsmodels]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.0 joblib-1.5.1 kiwisolver-1.4.8 matplotlib-3.10.5 patsy-1.0.1 scipy-1.16.1 statsmodels-0.14.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# STEP 3: Test all imports (run after all packages are installed)
import numpy as np
import pandas as pd
import matplotlib as mb
import matplotlib.pyplot as plt
import plotly as pl
import seaborn as sns
import sklearn as sk
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import feature_engine as fe
import sys
sys.path.append('../')

print("✅ All packages imported successfully!")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
print(f"Matplotlib version: {mb.__version__}")
print(f"Seaborn version: {sns.__version__}")
print(f"Scikit-learn version: {sk.__version__}")
print(f"Plotly version: {pl.__version__}")
print(f"Feature-engine version: {fe.__version__}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 # STEP 3: Test all imports (run after all packages are installed)
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import matplotlib as mb
#       5 import matplotlib.pyplot as plt
#
# File c:\Users\F_bee\Documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\Lib\site-packages\pandas\__init__.py:38
#      34 del _hard_dependencies, _dependency, _missing_dependencies
#      36 try:
#      37     # numpy compat
# ---> 38     from pandas.compat import (
#      39         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      40     )
#      41 except ImportError as _err:  # pragma: no cover
#      42     _module = _err.name
#
# File c:\Users\F_bee\Documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\Lib\site-packages\pandas\compat\__init__.py:27
#      25 import pandas.compat.compressors
#      26 from pandas.compat.numpy import is_numpy_dev
# ---> 27 from pandas.compat.pyarrow import (
#      28     HAS_PYARROW,
#      29     pa_version_under10p1,
#      30     pa_version_under11p0,
#      31     pa_version_under13p0,
#      32     pa_version_under14p0,
#      33     pa_version_under14p1,
#      34     pa_version_under16p0,
#      35     pa_version_under17p0,
#      36     pa_version_under18p0,
#      37     pa_version_under19p0,
#      38     pa_version_under20p0,
#      39     pa_version_under21p0,
#      40 )
#      42 if TYPE_CHECKING:
#      43     from pandas._typing import F
#
# File c:\Users\F_bee\Documents\vs-code\vs-code-projects\healthcare-and-public-health\.venv\Lib\site-packages\pandas\compat\pyarrow.py:10
#       7 try:
#       8     import pyarrow as pa
# ---> 10     _palv = Version(Version(pa.__version__).base_version)
#      11     pa_version_under10p1 = _palv < Version("10.0.1")
#      12     pa_version_under11p0 = _palv < Version("11.0.0")
#
# AttributeError: module 'pyarrow' has no attribute '__version__'

# %% [markdown]
# import numpy as np
# import seaborn as sns
# import matplotlib as mb
# import matplotlib.pyplot as plt
# import plotly as pl
# import pandas as pd
# import sklearn as sk
# from sklearn.preprocessing import FunctionTransformer
# from sklearn.pipeline import Pipeline
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import StandardScaler, OneHotEncoder
# import feature_engine as fe
# import sys
# sys.path.append('../')

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
